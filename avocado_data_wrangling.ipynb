# %% [markdown]
# <a href="https://colab.research.google.com/github/roshniharinkhede/python_projects/blob/main/avocado_data_wrangling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
url = 'https://raw.githubusercontent.com/roshniharinkhede/Dataset/main/avocado.csv'
avocado = pd.read_csv(url)
avocado.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  ...          type  year  region
# 0           0  2015-12-27          1.33  ...  conventional  2015  Albany
# 1           1  2015-12-20          1.35  ...  conventional  2015  Albany
# 2           2  2015-12-13          0.93  ...  conventional  2015  Albany
# 3           3  2015-12-06          1.08  ...  conventional  2015  Albany
# 4           4  2015-11-29          1.28  ...  conventional  2015  Albany
#
# [5 rows x 14 columns]

# %%
avocado = avocado.reset_index(drop=True)
avocado.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  ...          type  year  region
# 0           0  2015-12-27          1.33  ...  conventional  2015  Albany
# 1           1  2015-12-20          1.35  ...  conventional  2015  Albany
# 2           2  2015-12-13          0.93  ...  conventional  2015  Albany
# 3           3  2015-12-06          1.08  ...  conventional  2015  Albany
# 4           4  2015-11-29          1.28  ...  conventional  2015  Albany
#
# [5 rows x 14 columns]

# %%
avocado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    18249 non-null  int64
#  1   Date          18249 non-null  object
#  2   AveragePrice  18249 non-null  float64
#  3   Total Volume  18249 non-null  float64
#  4   4046          18249 non-null  float64
#  5   4225          18249 non-null  float64
#  6   4770          18249 non-null  float64
#  7   Total Bags    18249 non-null  float64
#  8   Small Bags    18249 non-null  float64
#  9   Large Bags    18249 non-null  float64
#  10  XLarge Bags   18249 non-null  float64
#  11  type          18249 non-null  object
#  12  year          18249 non-null  int64
#  13  region        18249 non-null  object
# dtypes: float64(9), int64(2), object(3)
# memory usage: 1.9+ MB

# %%
avocado.describe()
# Out:
#          Unnamed: 0  AveragePrice  ...    XLarge Bags          year
# count  18249.000000  18249.000000  ...   18249.000000  18249.000000
# mean      24.232232      1.405978  ...    3106.426507   2016.147899
# std       15.481045      0.402677  ...   17692.894652      0.939938
# min        0.000000      0.440000  ...       0.000000   2015.000000
# 25%       10.000000      1.100000  ...       0.000000   2015.000000
# 50%       24.000000      1.370000  ...       0.000000   2016.000000
# 75%       38.000000      1.660000  ...     132.500000   2017.000000
# max       52.000000      3.250000  ...  551693.650000   2018.000000
#
# [8 rows x 11 columns]

# %%
print(avocado.shape)
# Out:
# (18249, 14)

# %%
avocado.values
# Out:
# array([[0, '2015-12-27', 1.33, ..., 'conventional', 2015, 'Albany'],
#        [1, '2015-12-20', 1.35, ..., 'conventional', 2015, 'Albany'],
#        [2, '2015-12-13', 0.93, ..., 'conventional', 2015, 'Albany'],
#        ...,
#        [9, '2018-01-21', 1.87, ..., 'organic', 2018, 'WestTexNewMexico'],
#        [10, '2018-01-14', 1.93, ..., 'organic', 2018, 'WestTexNewMexico'],
#        [11, '2018-01-07', 1.62, ..., 'organic', 2018, 'WestTexNewMexico']],
#       dtype=object)

# %%
print(avocado.columns)
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %% [markdown]
# Appending & Concatenating Series

# %%
even = pd.Series([2,4,6,8,10])
odd = pd.Series([1,3,5,7,9])

res = even.append(odd)
res
# Out:
# 0     2
# 1     4
# 2     6
# 3     8
# 4    10
# 0     1
# 1     3
# 2     5
# 3     7
# 4     9
# dtype: int64

# %% [markdown]
# Sorting

# %%
# sort values based on "AveragePrice" (ascending) and "year" (descending)
avocado.sort_values(["AveragePrice", "year"], ascending=[True, False])
# Out:
#        Unnamed: 0        Date  ...  year             region
# 15261          43  2017-03-05  ...  2017   CincinnatiDayton
# 7412           47  2017-02-05  ...  2017      PhoenixTucson
# 15473          43  2017-03-05  ...  2017            Detroit
# 15262          44  2017-02-26  ...  2017   CincinnatiDayton
# 1716            0  2015-12-27  ...  2015      PhoenixTucson
# ...           ...         ...  ...   ...                ...
# 16720          18  2017-08-27  ...  2017  RaleighGreensboro
# 16055          42  2017-03-12  ...  2017  MiamiFtLauderdale
# 14124           7  2016-11-06  ...  2016       SanFrancisco
# 17428          37  2017-04-16  ...  2017              Tampa
# 14125           8  2016-10-30  ...  2016       SanFrancisco
#
# [18249 rows x 14 columns]

# %% [markdown]
# Subsetting

# %%
#Subsetting is used to get a slice of the original dataframe

# %%
# Subsetting columns
avocado["AveragePrice"]
# Out:
# 0        1.33
# 1        1.35
# 2        0.93
# 3        1.08
# 4        1.28
#          ...
# 18244    1.63
# 18245    1.71
# 18246    1.87
# 18247    1.93
# 18248    1.62
# Name: AveragePrice, Length: 18249, dtype: float64

# %%
#Subsetting multiple columns
# Subsetting multiple columns
avocado[["AveragePrice","Date"]]
# Out:
#        AveragePrice        Date
# 0              1.33  2015-12-27
# 1              1.35  2015-12-20
# 2              0.93  2015-12-13
# 3              1.08  2015-12-06
# 4              1.28  2015-11-29
# ...             ...         ...
# 18244          1.63  2018-02-04
# 18245          1.71  2018-01-28
# 18246          1.87  2018-01-21
# 18247          1.93  2018-01-14
# 18248          1.62  2018-01-07
#
# [18249 rows x 2 columns]

# %% [markdown]
# Subsetting rows

# %%
# Subsetting rows
avocado["AveragePrice"]<1
# Out:
# 0        False
# 1        False
# 2         True
# 3        False
# 4        False
#          ...
# 18244    False
# 18245    False
# 18246    False
# 18247    False
# 18248    False
# Name: AveragePrice, Length: 18249, dtype: bool

# %% [markdown]
# Subsetting based on text data

# %%
# it will print all the rows with "type" = "organic"
avocado[avocado["type"]=="organic"]
# Out:
#        Unnamed: 0        Date  AveragePrice  ...     type  year            region
# 9126            0  2015-12-27          1.83  ...  organic  2015            Albany
# 9127            1  2015-12-20          1.89  ...  organic  2015            Albany
# 9128            2  2015-12-13          1.85  ...  organic  2015            Albany
# 9129            3  2015-12-06          1.84  ...  organic  2015            Albany
# 9130            4  2015-11-29          1.94  ...  organic  2015            Albany
# ...           ...         ...           ...  ...      ...   ...               ...
# 18244           7  2018-02-04          1.63  ...  organic  2018  WestTexNewMexico
# 18245           8  2018-01-28          1.71  ...  organic  2018  WestTexNewMexico
# 18246           9  2018-01-21          1.87  ...  organic  2018  WestTexNewMexico
# 18247          10  2018-01-14          1.93  ...  organic  2018  WestTexNewMexico
# 18248          11  2018-01-07          1.62  ...  organic  2018  WestTexNewMexico
#
# [9123 rows x 14 columns]

# %% [markdown]
# Subsetting based on dates

# %%
# it will print all the rows with "Date" <= 2015-02-04
avocado[avocado["Date"]<="2015-02-04"]
# Out:
#        Unnamed: 0        Date  ...  year            region
# 47             47  2015-02-01  ...  2015            Albany
# 48             48  2015-01-25  ...  2015            Albany
# 49             49  2015-01-18  ...  2015            Albany
# 50             50  2015-01-11  ...  2015            Albany
# 51             51  2015-01-04  ...  2015            Albany
# ...           ...         ...  ...   ...               ...
# 11928          46  2015-02-01  ...  2015  WestTexNewMexico
# 11929          47  2015-01-25  ...  2015  WestTexNewMexico
# 11930          48  2015-01-18  ...  2015  WestTexNewMexico
# 11931          49  2015-01-11  ...  2015  WestTexNewMexico
# 11932          50  2015-01-04  ...  2015  WestTexNewMexico
#
# [540 rows x 14 columns]

# %% [markdown]
# Subsetting based on multiple conditions

# %%
# it will print all the rows with "Date" before 2015-02-04 and "type" == "organic"
avocado[(avocado["Date"]<"2015-02-04") & (avocado["type"]=="organic")]
# Out:
#        Unnamed: 0        Date  AveragePrice  ...     type  year            region
# 9173           47  2015-02-01          1.83  ...  organic  2015            Albany
# 9174           48  2015-01-25          1.89  ...  organic  2015            Albany
# 9175           49  2015-01-18          1.93  ...  organic  2015            Albany
# 9176           50  2015-01-11          1.77  ...  organic  2015            Albany
# 9177           51  2015-01-04          1.79  ...  organic  2015            Albany
# ...           ...         ...           ...  ...      ...   ...               ...
# 11928          46  2015-02-01          1.77  ...  organic  2015  WestTexNewMexico
# 11929          47  2015-01-25          1.63  ...  organic  2015  WestTexNewMexico
# 11930          48  2015-01-18          1.71  ...  organic  2015  WestTexNewMexico
# 11931          49  2015-01-11          1.69  ...  organic  2015  WestTexNewMexico
# 11932          50  2015-01-04          1.64  ...  organic  2015  WestTexNewMexico
#
# [270 rows x 14 columns]

# %% [markdown]
# Subsetting using .isin()

# %%
# subset the avocado in the region Boston or SanDiego
regionFilter = avocado["region"].isin(["Boston", "SanDiego"])
avocado[regionFilter]
# Out:
#        Unnamed: 0        Date  AveragePrice  ...          type  year    region
# 208             0  2015-12-27          1.13  ...  conventional  2015    Boston
# 209             1  2015-12-20          1.07  ...  conventional  2015    Boston
# 210             2  2015-12-13          1.01  ...  conventional  2015    Boston
# 211             3  2015-12-06          1.02  ...  conventional  2015    Boston
# 212             4  2015-11-29          1.19  ...  conventional  2015    Boston
# ...           ...         ...           ...  ...           ...   ...       ...
# 18100           7  2018-02-04          1.81  ...       organic  2018  SanDiego
# 18101           8  2018-01-28          1.91  ...       organic  2018  SanDiego
# 18102           9  2018-01-21          1.95  ...       organic  2018  SanDiego
# 18103          10  2018-01-14          1.81  ...       organic  2018  SanDiego
# 18104          11  2018-01-07          2.06  ...       organic  2018  SanDiego
#
# [676 rows x 14 columns]

# %% [markdown]
# Multiple parameter Filtering

# %%
# subset the avocado in the region Boston or SanDiego in the year 2016 or 2017
regionFilter = avocado["region"].isin(["Boston", "SanDiego"])
yearFilter = avocado["year"].isin(["2016", "2017"])
avocado[regionFilter & yearFilter]
# Out:
#        Unnamed: 0        Date  AveragePrice  ...          type  year    region
# 3016            0  2016-12-25          1.28  ...  conventional  2016    Boston
# 3017            1  2016-12-18          1.09  ...  conventional  2016    Boston
# 3018            2  2016-12-11          1.22  ...  conventional  2016    Boston
# 3019            3  2016-12-04          1.26  ...  conventional  2016    Boston
# 3020            4  2016-11-27          1.45  ...  conventional  2016    Boston
# ...           ...         ...           ...  ...           ...   ...       ...
# 16962          48  2017-01-29          1.21  ...       organic  2017  SanDiego
# 16963          49  2017-01-22          1.73  ...       organic  2017  SanDiego
# 16964          50  2017-01-15          1.82  ...       organic  2017  SanDiego
# 16965          51  2017-01-08          1.52  ...       organic  2017  SanDiego
# 16966          52  2017-01-01          1.45  ...       organic  2017  SanDiego
#
# [420 rows x 14 columns]

# %% [markdown]
# Detecting missing values .isna()

# %%
avocado.isna()
# Out:
#        Unnamed: 0   Date  AveragePrice  ...   type   year  region
# 0           False  False         False  ...  False  False   False
# 1           False  False         False  ...  False  False   False
# 2           False  False         False  ...  False  False   False
# 3           False  False         False  ...  False  False   False
# 4           False  False         False  ...  False  False   False
# ...           ...    ...           ...  ...    ...    ...     ...
# 18244       False  False         False  ...  False  False   False
# 18245       False  False         False  ...  False  False   False
# 18246       False  False         False  ...  False  False   False
# 18247       False  False         False  ...  False  False   False
# 18248       False  False         False  ...  False  False   False
#
# [18249 rows x 14 columns]

# %% [markdown]
# We can use .any() function to get a consise info

# %%
avocado.isna().any()
# Out:
# Unnamed: 0      False
# Date            False
# AveragePrice    False
# Total Volume    False
# 4046            False
# 4225            False
# 4770            False
# Total Bags      False
# Small Bags      False
# Large Bags      False
# XLarge Bags     False
# type            False
# year            False
# region          False
# dtype: bool

# %% [markdown]
# Counting missing values

# %%
avocado.isna().sum()
# Out:
# Unnamed: 0      0
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %% [markdown]
# Removing missing values
# Drop NaN .dropna()
# Fill NaN with value x .fillna(x)

# %%
# Luckily we don't have any NaN but if we have we can use any of the two methods

avocado.dropna()
# Out:
#        Unnamed: 0        Date  ...  year            region
# 0               0  2015-12-27  ...  2015            Albany
# 1               1  2015-12-20  ...  2015            Albany
# 2               2  2015-12-13  ...  2015            Albany
# 3               3  2015-12-06  ...  2015            Albany
# 4               4  2015-11-29  ...  2015            Albany
# ...           ...         ...  ...   ...               ...
# 18244           7  2018-02-04  ...  2018  WestTexNewMexico
# 18245           8  2018-01-28  ...  2018  WestTexNewMexico
# 18246           9  2018-01-21  ...  2018  WestTexNewMexico
# 18247          10  2018-01-14  ...  2018  WestTexNewMexico
# 18248          11  2018-01-07  ...  2018  WestTexNewMexico
#
# [18249 rows x 14 columns]

# %%
# ****  OR  ****

# %%
meanVal = avocado["AveragePrice"].mean()
avocado.fillna(meanVal)
# Out:
#        Unnamed: 0        Date  ...  year            region
# 0               0  2015-12-27  ...  2015            Albany
# 1               1  2015-12-20  ...  2015            Albany
# 2               2  2015-12-13  ...  2015            Albany
# 3               3  2015-12-06  ...  2015            Albany
# 4               4  2015-11-29  ...  2015            Albany
# ...           ...         ...  ...   ...               ...
# 18244           7  2018-02-04  ...  2018  WestTexNewMexico
# 18245           8  2018-01-28  ...  2018  WestTexNewMexico
# 18246           9  2018-01-21  ...  2018  WestTexNewMexico
# 18247          10  2018-01-14  ...  2018  WestTexNewMexico
# 18248          11  2018-01-07  ...  2018  WestTexNewMexico
#
# [18249 rows x 14 columns]

# %% [markdown]
# Adding a new column

# %% [markdown]
# It can easily be done using the [ ] brackets

# %%
#Lets add a new column to our dataframe called AveragePricePer100

avocado["AveragePricePer100"] = avocado["AveragePrice"] * 100
avocado
# Out:
#        Unnamed: 0        Date  ...            region  AveragePricePer100
# 0               0  2015-12-27  ...            Albany               133.0
# 1               1  2015-12-20  ...            Albany               135.0
# 2               2  2015-12-13  ...            Albany                93.0
# 3               3  2015-12-06  ...            Albany               108.0
# 4               4  2015-11-29  ...            Albany               128.0
# ...           ...         ...  ...               ...                 ...
# 18244           7  2018-02-04  ...  WestTexNewMexico               163.0
# 18245           8  2018-01-28  ...  WestTexNewMexico               171.0
# 18246           9  2018-01-21  ...  WestTexNewMexico               187.0
# 18247          10  2018-01-14  ...  WestTexNewMexico               193.0
# 18248          11  2018-01-07  ...  WestTexNewMexico               162.0
#
# [18249 rows x 15 columns]

# %% [markdown]
# Deleting columns in DataFrame .drop(lst,axis = 1)

# %% [markdown]
# dataFrame.drop(['COLUMN_NAME'], axis = 1)

# %% [markdown]
# .the first parameter is a list of columns to be deleted
# .axis = 1 means delete column
# .axis = 0 means delete row

# %%
avocado.drop(["AveragePricePer100"],axis = 1)
# Out:
#        Unnamed: 0        Date  ...  year            region
# 0               0  2015-12-27  ...  2015            Albany
# 1               1  2015-12-20  ...  2015            Albany
# 2               2  2015-12-13  ...  2015            Albany
# 3               3  2015-12-06  ...  2015            Albany
# 4               4  2015-11-29  ...  2015            Albany
# ...           ...         ...  ...   ...               ...
# 18244           7  2018-02-04  ...  2018  WestTexNewMexico
# 18245           8  2018-01-28  ...  2018  WestTexNewMexico
# 18246           9  2018-01-21  ...  2018  WestTexNewMexico
# 18247          10  2018-01-14  ...  2018  WestTexNewMexico
# 18248          11  2018-01-07  ...  2018  WestTexNewMexico
#
# [18249 rows x 14 columns]

# %% [markdown]
# Summary statistics

# %% [markdown]
# .median() .mode() .min() .max() .var() .std() .sum() .quantile()

# %%
# mean of the AveragePrice of avocado
avocado["AveragePrice"].mean()
# Out:
# 1.4059784097758825

# %% [markdown]
# Summarizing dates

# %%
avocado["Date"].max()
# Out:
# '2018-03-25'

# %% [markdown]
# .agg() method

# %%
#Pandas Series.agg() is used to pass a function or list of function to be applied on a series or even each element of series separately.

#Syntax: Series.agg(func, axis=0)

#Parameters: func: Function, list of function or string of function name to be called on Series. axis:0 or ‘index’ for row wise operation and 1 or ‘columns’ for column wise operation.

#Return Type: The return type depends on return type of function passed as parameter.

# %%
def pct30(column):
    #return the 0.3 quartile
    return column.quantile(0.3)
def pct50(column):
    #return the 0.5 quartile
    return column.quantile(0.5)

avocado[["AveragePrice","Total Bags"]].agg([pct30,pct50])
# Out:
#        AveragePrice  Total Bags
# pct30          1.15    7316.634
# pct50          1.37   39743.830

# %% [markdown]
# Dropping duplicate names .drop_duplicates(lst)

# %%
#Delete all the duplicate names from the dataframe

temp = avocado.drop_duplicates(subset=["year"])
temp
# Out:
#       Unnamed: 0        Date  AveragePrice  ...  year  region  AveragePricePer100
# 0              0  2015-12-27          1.33  ...  2015  Albany               133.0
# 2808           0  2016-12-25          1.52  ...  2016  Albany               152.0
# 5616           0  2017-12-31          1.47  ...  2017  Albany               147.0
# 8478           0  2018-03-25          1.57  ...  2018  Albany               157.0
#
# [4 rows x 15 columns]

# %% [markdown]
# Count categorical data .value_counts()

# %%
# count number of avocado in each year in descending order
avocado["year"].value_counts(sort=True, ascending = False)
# Out:
# 2017    5722
# 2016    5616
# 2015    5615
# 2018    1296
# Name: year, dtype: int64

# %% [markdown]
# Grouped summaries .groupby(col)

# %%
# group by multiple columns and perform multiple summary statistic operations
avocado.groupby(["year","type"])["AveragePrice"].agg([min,max,np.mean,np.median])
# Out:
#                     min   max      mean  median
# year type
# 2015 conventional  0.49  1.59  1.077963    1.08
#      organic       0.81  2.79  1.673324    1.67
# 2016 conventional  0.51  2.20  1.105595    1.08
#      organic       0.58  3.25  1.571684    1.53
# 2017 conventional  0.46  2.22  1.294888    1.30
#      organic       0.44  3.17  1.735521    1.72
# 2018 conventional  0.56  1.74  1.127886    1.14
#      organic       1.01  2.30  1.567176    1.55

# %% [markdown]
# Pivot table

# %%
#A pivot table is a table of statistics that summarizes the data of a more extensive table.

# %% [markdown]
# Syntax

# %%
#pandas.pivot_table(data, values=None, index=None, columns=None, aggfunc=’mean’, fill_value=None, margins=False, dropna=True, margins_name=’All’)

# %%
# this is the same table we build in the previous cell but using pivot table
avocado.pivot_table(index=["year","type"], aggfunc=[min,max,np.mean,np.median], values="AveragePrice")
# Out:
#                            min          max         mean       median
#                   AveragePrice AveragePrice AveragePrice AveragePrice
# year type
# 2015 conventional         0.49         1.59     1.077963         1.08
#      organic              0.81         2.79     1.673324         1.67
# 2016 conventional         0.51         2.20     1.105595         1.08
#      organic              0.58         3.25     1.571684         1.53
# 2017 conventional         0.46         2.22     1.294888         1.30
#      organic              0.44         3.17     1.735521         1.72
# 2018 conventional         0.56         1.74     1.127886         1.14
#      organic              1.01         2.30     1.567176         1.55

# %% [markdown]
# Setting column as the index

# %%
regionIndex = avocado.set_index(["region"])
regionIndex
# Out:
#                   Unnamed: 0        Date  ...  year  AveragePricePer100
# region                                    ...
# Albany                     0  2015-12-27  ...  2015               133.0
# Albany                     1  2015-12-20  ...  2015               135.0
# Albany                     2  2015-12-13  ...  2015                93.0
# Albany                     3  2015-12-06  ...  2015               108.0
# Albany                     4  2015-11-29  ...  2015               128.0
# ...                      ...         ...  ...   ...                 ...
# WestTexNewMexico           7  2018-02-04  ...  2018               163.0
# WestTexNewMexico           8  2018-01-28  ...  2018               171.0
# WestTexNewMexico           9  2018-01-21  ...  2018               187.0
# WestTexNewMexico          10  2018-01-14  ...  2018               193.0
# WestTexNewMexico          11  2018-01-07  ...  2018               162.0
#
# [18249 rows x 14 columns]

# %%
# Insted of doing this
avocado[avocado["region"].isin(["Albany", "WestTexNewMexico"])]
# Out:
#        Unnamed: 0        Date  ...            region  AveragePricePer100
# 0               0  2015-12-27  ...            Albany               133.0
# 1               1  2015-12-20  ...            Albany               135.0
# 2               2  2015-12-13  ...            Albany                93.0
# 3               3  2015-12-06  ...            Albany               108.0
# 4               4  2015-11-29  ...            Albany               128.0
# ...           ...         ...  ...               ...                 ...
# 18244           7  2018-02-04  ...  WestTexNewMexico               163.0
# 18245           8  2018-01-28  ...  WestTexNewMexico               171.0
# 18246           9  2018-01-21  ...  WestTexNewMexico               187.0
# 18247          10  2018-01-14  ...  WestTexNewMexico               193.0
# 18248          11  2018-01-07  ...  WestTexNewMexico               162.0
#
# [673 rows x 15 columns]

# %%
# we can simply do
regionIndex.loc[["Albany", "WestTexNewMexico"]]
# Out:
#                   Unnamed: 0        Date  ...  year  AveragePricePer100
# region                                    ...
# Albany                     0  2015-12-27  ...  2015               133.0
# Albany                     1  2015-12-20  ...  2015               135.0
# Albany                     2  2015-12-13  ...  2015                93.0
# Albany                     3  2015-12-06  ...  2015               108.0
# Albany                     4  2015-11-29  ...  2015               128.0
# ...                      ...         ...  ...   ...                 ...
# WestTexNewMexico           7  2018-02-04  ...  2018               163.0
# WestTexNewMexico           8  2018-01-28  ...  2018               171.0
# WestTexNewMexico           9  2018-01-21  ...  2018               187.0
# WestTexNewMexico          10  2018-01-14  ...  2018               193.0
# WestTexNewMexico          11  2018-01-07  ...  2018               162.0
#
# [673 rows x 14 columns]

# %% [markdown]
# Visualizing your data

# %% [markdown]
# Histograms

# %%
#use the function .hist()

avocado["AveragePrice"].hist(bins=20)
plt.show()

# %% [markdown]
# Bar plots

# %%
regionFilter = avocado.groupby("region")["AveragePrice"].mean().head(10)
regionFilter
# Out:
# region
# Albany                 1.561036
# Atlanta                1.337959
# BaltimoreWashington    1.534231
# Boise                  1.348136
# Boston                 1.530888
# BuffaloRochester       1.516834
# California             1.395325
# Charlotte              1.606036
# Chicago                1.556775
# CincinnatiDayton       1.209201
# Name: AveragePrice, dtype: float64

# %%
regionFilter.plot(kind = "bar",rot=45,title="Average price in 10 regions")

# %% [markdown]
# Scatter plot

# %%
avocado.plot(x="AveragePrice", y="Total Volume", kind="scatter")
